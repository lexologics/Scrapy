# %%
import pandas as pd
import datetime

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('gamesps4_2021-02-06T07-39-02.csv')
df['game_price'] = df['game_price'].map(lambda x: x.lstrip('<td>€').rstrip('</td>'))

# %%
#df

# %%
day = datetime.datetime.now().day
month = datetime.datetime.now().month
year = datetime.datetime.now().year
hour = datetime.datetime.now().hour
minute = datetime.datetime.now().minute
second = datetime.datetime.now().second
date = str(year) + '-' + str(month) + '-' + str(day) + '_' + str(hour) + '-' + str(minute)
date

df.to_csv(f'gamesps4-{date}.csv', index=None)

# %%
start_urls = []

for i in range(1,77):
    #print(f'https://www.budgetgaming.nl/gamesonly/{i}/console-ps4.html')
    start_urls.append(f'https://www.budgetgaming.nl/gamesonly/{i}/console-ps4.html')

# %%
start_urls
# Out:
# ['https://www.budgetgaming.nl/gamesonly/1/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/2/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/3/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/4/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/5/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/6/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/7/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/8/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/9/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/10/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/11/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/12/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/13/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/14/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/15/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/16/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/17/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/18/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/19/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/20/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/21/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/22/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/23/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/24/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/25/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/26/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/27/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/28/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/29/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/30/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/31/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/32/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/33/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/34/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/35/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/36/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/37/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/38/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/39/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/40/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/41/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/42/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/43/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/44/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/45/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/46/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/47/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/48/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/49/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/50/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/51/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/52/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/53/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/54/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/55/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/56/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/57/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/58/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/59/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/60/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/61/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/62/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/63/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/64/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/65/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/66/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/67/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/68/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/69/console-ps4.html',
#  'https://www.budgetgaming.nl/gamesonly/70/console-ps4.html']

# %%
df = pd.read_csv('gamesps4-2021-2-6_8-16.csv')

df2 = pd.read_csv('gamesps4-2021-2-6_8-39.csv')


df.compare(df2, keep_equal=True, keep_shape=True)
# Out:
#                                           game_name  \
#                                                self
# 0                           .hack//G.U. Last Recode
# 1                            11-11: Memories Retold
# 2                           13 Sentinels: AEGIS RIM
# 3                               1971 Project Helios
# 4                             2Dark Limited Edition
# ...                                             ...
# 2248  Zombie Army 4: Dead War - Collector's Edition
# 2249                            Zombie Army Trilogy
# 2250                Zombie Vikings Ragnarok Edition
# 2251                Zombieland: Double Tap Roadtrip
# 2252   Zone of the Enders: The 2nd Runner - MARS VR
#
#                                                     game_price          \
#                                               other       self   other
# 0                           .hack//G.U. Last Recode      25.42   25.42
# 1                            11-11: Memories Retold      11.88   11.88
# 2                           13 Sentinels: AEGIS RIM      54.99   54.99
# 3                               1971 Project Helios      19.99   19.99
# 4                             2Dark Limited Edition      58.05   58.05
# ...                                             ...        ...     ...
# 2248                        Zombie Army 4: Dead War              34.88
# 2249  Zombie Army 4: Dead War - Collector's Edition      22.84
# 2250                            Zombie Army Trilogy      22.98   22.84
# 2251                Zombieland: Double Tap Roadtrip      28.99   28.99
# 2252   Zone of the Enders: The 2nd Runner - MARS VR      14.49   14.49
#
#         game_cheapest
#                  self            other
# 0           Amazon.nl        Amazon.nl
# 1     Gameshop Twente  Gameshop Twente
# 2          Nedgame.nl       Nedgame.nl
# 3     Bol.com Partner  Bol.com Partner
# 4      Game-Outlet NL   Game-Outlet NL
# ...               ...              ...
# 2248                   Gameshop Twente
# 2249        Amazon.nl
# 2250       Nedgame.nl        Amazon.nl
# 2251  Bol.com Partner  Bol.com Partner
# 2252        Amazon.nl        Amazon.nl
#
# [2253 rows x 6 columns]
